# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-family: 'Arial Black', Gadget, sans-serif; color: #2c3e50; font-size: 32px; text-shadow: 3px 3px 6px rgba(0, 0, 0, 0.2);">Introduction to AI Programming</span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-family: 'Georgia', serif; color: #8e44ad; font-size: 28px;">Python Introduction, Installation</span>
# </div>
#
# _________________
#
# <div
#     style="
#         margin: 50px auto;
#         padding: 30px 20px;
#         border: 2px solid #333;
#         border-radius: 15px;
#         background: #ffffff;
#         max-width: 700px;
#         box-shadow: 0 6px 15px rgba(0, 0, 0, 0.1);
#         text-align: center;
#     "
# >
#     <h2
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 28px;
#             color: #2c3e50;
#             text-transform: uppercase;
#             font-weight: bold;
#             letter-spacing: 1.5px;
#         "
#     >
#         Course Title
#     </h2>
#     <h1
#         style="
#             font-family: 'Times New Roman', serif;
#             font-size: 24px;
#             color: #34495e;
#             margin-top: 10px;
#         "
#     >
#         Introduction to AI Programming
#     </h1>
# </div

# %% [markdown]
# # Assignment No:1
# ### Name:-------Mughees ud din
# ### Reg no:-----24JZELE0560
# ---

# %% [markdown]
# 1.	Load the CSV manually using the csv module (not pandas).
# 2.	Store the consumption column in a list of floats.
# 	 Compute:
#   	2.1 Total consumption
#   	2.2 Average consumption
#   	2.3 Maximum and minimum
# 3.	Use a list comprehension to convert hourly consumption into kWh.
# 4.	Print all results in a clean format.

# %%
import csv    #1.importing csv module
consumption=[]
with open(r"D:\3rd semester\introduction to AI\Assignments and OEL\Assignment 1.csv") as file:  #reading given file.
 reader=csv.reader(file)
 for index,r in enumerate(reader):
  if index==0:
    continue
  consumption.append(float(r[1]))   #2.storing consumption column in list

# %%
total_consumption=sum(consumption)  #2.1 calculating total consumption

avg=total_consumption/len(consumption)  #2.2 calculating average consumption

# %%
mx=max(consumption)  #2.3 maximum 
mn=min(consumption) #2.3 minimum

# %%
kwh=[x/1000 for x in consumption]   #3.converting hourly consumption in Kwh by list comprehension

# %%
#4.printing all results
print("consumption column in list of float ->",consumption)
print("Total consumption in given column: ",total_consumption)
print("average consumption: ",avg)
print("maximum power consumed: ",mx)
print("minimum power consumed",mn)
print("list of consumption column in KWh ->",kwh)
# Out:
# consumption column in list of float -> [200.0, 300.0, 500.0, 700.0, 600.0, 400.0, 800.0, 700.0, 600.0, 500.0]
# Total consumption in given column:  5300.0
# average consumption:  530.0
# maximum power consumed:  800.0
# minimum power consumed 200.0
# list of consumption column in KWh -> [0.2, 0.3, 0.5, 0.7, 0.6, 0.4, 0.8, 0.7, 0.6, 0.5]
