# %% [markdown]
# ## Create dictionary from a list
# Given: names = ["Ali", "Sara", "Bilal"]
# Create a dictionary where each name maps to its length.
# {key: value for item in iterable}

# %%
names = ["Ali", "Sara", "Bilal"]  
names_dictionary={x:len(x) for x in names}
names_dictionary
# Out:
# {'Ali': 3, 'Sara': 4, 'Bilal': 5}

# %% [markdown]
# ---
# ## Filter a dictionary using comprehension
# Given:scores = {"Ali": 55, "Sara": 82, "Bilal": 40, "John": 90}
# Create a new dictionary containing only the students who scored 60 or above.
# {k: v for k, v in dict.items() if condition}

# %%
scores = {"Ali": 55, "Sara": 82, "Bilal": 40, "John": 90}  
pass_students={x:y for x,y in scores.items() if y>60 }
pass_students
# Out:
# {'Sara': 82, 'John': 90}

# %% [markdown]
# ---
# ## Swap keys and values
# Given:pairs = {"a": 1, "b": 2, "c": 3}
# Use a dictionary comprehension to swap keys and values.

# %%
pairs = {"a": 1, "b": 2, "c": 3}  
pairs={y:x for x,y in pairs.items()}
pairs
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %% [markdown]
# ---
# ## Transform dictionary values
# Given:prices = {"pen": 10, "book": 50, "bag": 100}
# Use a dictionary comprehension to apply a 10% discount to each price.

# %%
prices = {"pen": 10, "book": 50, "bag": 100}
discounted_prices={x:y-y*0.10 for x,y in prices.items()}
discounted_prices
# Out:
# {'pen': 9.0, 'book': 45.0, 'bag': 90.0}
