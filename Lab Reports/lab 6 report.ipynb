# %% [markdown]
# ## Scenario:
# You are designing a small student management system. You need to maintain student data for a class. Each   student has a name, a roll number, and a list of grades. The system must allow grade updates but keep roll numbers fixed.
# Tasks:
# 1.	Create a list of student names: ["Ali", "Usman", "Hassan", "Kamran"].
# 2.	Create a tuple of student roll numbers: (101, 102, 103, 104).
# 3.	For each student, create a list of grades (3 subjects) using nested lists:
# Example: [ [85, 90, 78], [88, 92, 80], ... ]
# 4.	Update Ali’s second grade to 95.
# 5.	Add a new grade for Hassan in the fourth subject.
# 6.	Attempt to change Kamran’s roll number and observe what happens. Explain why.
# 7.	Print all students' names with their updated grades in a readable format.

# %%
#1
names=["Ali", "Usman", "Hassan", "Kamran"]
#2
rollnumbers=(101,102,103,104)
#3
grades=[[85,78,96],[88,92,80],[99,89,98],[88,87,97]]

# %%
#4
grades[0][1]=95
grades
# Out:
# [[85, 95, 96], [88, 92, 80], [99, 89, 98], [88, 87, 97]]

# %%
#5
grades[2].append(100)
grades
# Out:
# [[85, 95, 96], [88, 92, 80], [99, 89, 98, 100], [88, 87, 97]]

# %%
#6
rollnumbers[3]=105
rollnumbers
#tuples are immutable so its causing error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 #6
# ----> 2 rollnumbers[3]=105
#       3 rollnumbers
#       4 #tuples are immutable so its causing error
#
# TypeError: 'tuple' object does not support item assignment

# %%
#7
[print(f"Student name: {n}, having grades: {g}") for n,g in zip(names,grades)]
# Out:
# student name: Ali, having grades: [85, 95, 96]
# student name: Usman, having grades: [88, 92, 80]
# student name: Hassan, having grades: [99, 89, 98, 100]
# student name: Kamran, having grades: [88, 87, 97]
# [None, None, None, None]
