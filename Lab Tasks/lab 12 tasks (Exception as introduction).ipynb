# %% [markdown]
# In the below task first run the code then understand the error and fix the code with exception handling.
# ## Task 1: Type Error (Add int and string)
# Step 1: Run This Code
# a = 10
# b = "5"
# result = a + b
# print(result)
# What Happens:
# The program crashes due to incompatible data types(Understand the error).
# Use the Following Concepts
# 	try
# 	except
# 	TypeError

# %%
a = 10
b = "5"
result = a + b
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 a = 10
#       2 b = "5"
# ----> 3 result = a + b
#       4 print(result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    a = 10
    b = "5"
    result = a + b
    print(result)
except TypeError as error:
    print(error)
    print("mistake found in code")
# Out:
# unsupported operand type(s) for +: 'int' and 'str'
# mistake found in code

# %% [markdown]
# ---
# ## Task 2: Division by Zero
# Step 1: Run This Code
# x = 20
# y = 0
# result = x / y
# print(result)
# What Happens
# The program terminates due to division by zero(Understand the error).
# Step 2: Fix the Code
# Handle the exception and display a meaningful error message.
# Use the Following Concepts
# 	try
# 	except
# 	ZeroDivisionError

# %%
x = 20  
y = 0  
result = x / y  
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 x = 20
#       2 y = 0
# ----> 3 result = x / y
#       4 print(result)
#
# ZeroDivisionError: division by zero

# %%
try:
    x = 20  
    y = 0  
    result = x / y  
    print(result)  
except ZeroDivisionError as error:
    print(error)
    print('number is divded by 0')
# Out:
# division by zero
# number is divded by 0

# %% [markdown]
# ---
# ## Task 3: List Index Out of Range
# Step 1: Run This Code
# numbers = [10, 20, 30]
# print(numbers[5])
# What Happens:
# The program crashes due to invalid index access.
# Step 2: Fix the Code
# Catch the exception and display a message indicating the index is invalid.
# Use the Following Concepts
# 	try
# 	except
# 	IndexError

# %%
numbers = [10, 20, 30]  
print(numbers[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 numbers = [10, 20, 30]
# ----> 2 print(numbers[5])
#
# IndexError: list index out of range

# %%
try:
    numbers = [10, 20, 30]  
    print(numbers[5])  
except IndexError as error:
    print(error)
    print("index is not correct")
# Out:
# list index out of range
# index is not correct

# %% [markdown]
# ---
# ## Task 4: Logical Error Using raise
# Step 1: Run This Code
# age = -5
# print("Age:", age)
#
# What Happens
# The program runs, but the data is logically incorrect.
# Step 2: Fix the Code
# Modify the program to detect the invalid value and raise an exception manually.
# Use the Following Concepts
# 	raise
# 	Exception

# %%
age = -5  
print("Age:", age)
# Out:
# Age: -5

# %%
age = -5  
print("Age:", age)  
if age<0:
    raise Exception(f"age is not valid age: {age}")
# Out:
# Age: -5
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 print("Age:", age)
#       3 if age<0:
# ----> 4     raise Exception(f"age is not valid age: {age}")
#
# Exception: age is not valid age: -5

# %% [markdown]
# ---
# ## Task 5: Assert Failure
# Step 1: Run This Code
# total_marks = 0
# assert total_marks > 0
# print("Total marks:", total_marks)
#
# What Happens
# The program stops due to a failed assertion.
# Step 2: Fix the Code
# Correct the condition or handle the assertion failure properly.
# Use the Following Concepts
# •	assert
# •	AssertionError

# %%
total_marks = 0  
assert total_marks > 0  
print("Total marks:", total_marks)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 total_marks = 0
# ----> 2 assert total_marks > 0
#       3 print("Total marks:", total_marks)
#
# AssertionError:

# %%
total_marks = 0  
assert (total_marks > 0),"total marks are less or equal to zero"
print("Total marks:", total_marks)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 total_marks = 0
# ----> 2 assert (total_marks > 0),"total marks are less or equal to zero"
#       3 print("Total marks:", total_marks)
#
# AssertionError: total marks are less or equal to zero

# %% [markdown]
# ---
# ## Task 6: Assert Failure
#
# try:
#     x = int("2")
# except ValueError:
#     print("Error")
# else:
#     print("No error occurred")
# finally:
#     print("Always executed")
#
# Run this code and understand by changing the code.

# %%
try:
    x = int("2b")
except ValueError:
    print("Error")
else:
    print("No error occurred")
finally:
    print("Always executed")
# Out:
# Error
# Always executed
