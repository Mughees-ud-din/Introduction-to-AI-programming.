# %% [markdown]
# ## Task 1: Map Device Names to Their Power Ratings
# Given: devices = ["Fan", "Light", "AC", "Pump"]
# power = [60, 15, 1800, 750]
# Create a dict using comprehension:
# {"Fan": 60, "Light": 15, ...}

# %%
devices = ["Fan", "Light", "AC", "Pump"]
power = [60, 15, 1800, 750]  
devices_powers={x:y for x,y in zip(devices,power)}
devices_powers
# Out:
# {'Fan': 60, 'Light': 15, 'AC': 1800, 'Pump': 750}

# %% [markdown]
# ---
# ## Task 2: Categorize Resistances as “Low” or “High”
# Resistance values (ohms):
# R = [5, 33, 47, 82, 10]
# Create a dict:
# Key = value, Value = "Low" if R < 40 else "High".

# %%
R = [5, 33, 47, 82, 10]  
resistance={x:"low" if x<40 else "high" for x in R }
resistance
# Out:
# {5: 'low', 33: 'low', 47: 'high', 82: 'high', 10: 'low'}

# %% [markdown]
# ---
# ## Task 3: Compute Current for Each Load
# Loads in watts:
# loads = [60, 100, 150, 200]
# Assume voltage = 200 V
# Dictionary comprehension to produce:
# {load: load/200} (I = P/V)

# %%
loads = [60, 100, 150, 200]  
voltage = 200
currents=[x/voltage for x in loads]
currents
# Out:
# [0.3, 0.5, 0.75, 1.0]

# %% [markdown]
# ---
# ## Task 4: Convert Dictionary Values From °C to °F
# Given:temps_c = {"motor": 40, "transformer": 60, "room": 28}
# Use dict comprehension to convert to Fahrenheit.

# %%
temps_c = {"motor": 40, "transformer": 60, "room": 28}  
temp_f={x:(temp*9)/5+32 for x,temp in temps_c.items()}
temp_f
# Out:
# {'motor': 104.0, 'transformer': 140.0, 'room': 82.4}

# %% [markdown]
# ---
# ## Task 5: Create Dict of Components With Index Keys
# Given component names:
# components = ["Resistor", "Capacitor", "Inductor", "Diode"]
# Create {0:"Resistor", 1:"Capacitor", ...}
# Using dict comprehension + enumerate.

# %%
components = ["Resistor", "Capacitor", "Inductor", "Diode"] 
components={i:v for i,v in enumerate(components)}
components
# Out:
# {0: 'Resistor', 1: 'Capacitor', 2: 'Inductor', 3: 'Diode'}

# %% [markdown]
# ---
# ## Task 6: Filter Only Devices With Power > 100W
# Given:device_power = {"Fan": 60, "Light": 15, "Heater": 1200, "Iron": 1000, "Router": 10}
# Use dict comprehension to keep only items where value > 100.

# %%
device_power = {"Fan": 60, "Light": 15, "Heater": 1200, "Iron": 1000, "Router": 10}
filtered={x:y for x,y in device_power.items() if y>100}
filtered
# Out:
# {'Heater': 1200, 'Iron': 1000}
